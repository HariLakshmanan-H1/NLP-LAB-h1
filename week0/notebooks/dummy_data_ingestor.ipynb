# %%
import pandas as pd

# %%
data = {
    'Review_ID': [101, 102, 103, 104, 105, 106, 107, 108, 109, 110],
    'Source': ['Twitter', 'AppStore', 'AppStore', 'Reddit', 'Twitter', 'Reddit', 'AppStore', 'Twitter', 'Reddit', 'AppStore'],
    'Sentiment_Label': ['Positive', 'Negative', 'Positive', 'Neutral', 'Negative', 'Neutral', 'Positive', 'Negative', 'Positive', 'Positive'],
    'Sentiment_Score': [0.95, 0.12, 0.88, 0.55, 0.05, 0.48, 0.92, 0.20, 0.78, 0.85],
    'Word_Count': [12, 45, 10, 85, 120, 60, 15, 30, 50, 8],
    # Simulating a "Gold Label" vs "Predicted" for heatmap later
    'Actual_Label': ['Positive', 'Negative', 'Positive', 'Negative', 'Negative', 'Neutral', 'Positive', 'Negative', 'Neutral', 'Positive']
}

df_nlp = pd.DataFrame(data)

# Save to files
df_nlp.to_csv('../datasets/reviews.csv', index=False)
df_nlp.to_json('../datasets/reviews.json', orient='records')
df_nlp.to_csv('../datasets/reviews.txt', sep='\t', index=False)
